# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio #

# %% [markdown]
# ## Eric TUYIZERE ##
#     From Rwanda

# %% [markdown]
# *I am interested in data scince because I want provide answers to the community based on evidence derived from data*
# ## Data science Language ##
# * Python
# * R
# * SQL
# * Julia
# * MATLAB

# %% [markdown]
# # The following code will verfy the reminder of 7 and 3 if it is equal to 1 #

# %%
reminder= 7%3
reminder==1
# Out:
# True

# %% [markdown]
# # The following code will convert minute to hours #

# %%
minutes = 150  
hours = minutes // 60  
remaining_minutes = minutes % 60  
print(f"{minutes} minutes is equal to {hours} hours and {remaining_minutes} minutes.")
# Out:
# 150 minutes is equal to 2 hours and 30 minutes.

# %% [markdown]
# ![Kigali](https://www.msc.com/-/media/images/msc-cargo/news-room/events/2023/african-fine-coffees-conference/kigali-conference-center_external.jpg?h=640&w=1000&la=ko-KR&hash=A1B9814A4F44F97BC3100777E6345B67)

# %% [markdown]
# ## Data Science Libraries ##
# * Numpy
# * Pandas
# * Matplotlib
# * Seaborn
# * Scikit-learn
# * TensorFlow
# * ggplot2
# * caret

# %% [markdown]
# # Data science Tools #
#  |Open source|commercial tools|
#  |-----------|----------------|
#  |SQL,MangoDB| Tableau        |
#  |Air Flow   |SPSS            |
#  |Jupter     |Excel           |

# %% [markdown]
# ## Multiplication and addition ##

# %%
1235453 *13 + 1234
# Out:
# 16062123

# %% [markdown]
#  ## List of objectives ##
#  * Eploration
#  * Learning
#  * Exercise
#  * Practice

# %% [markdown]
# # Author name: Eric TUYIZERE #
